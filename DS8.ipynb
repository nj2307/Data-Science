# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.size
# Out:
# 13365

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(x='class', data=df,palette='Pastel2')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x="sex", hue="survived", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Create a scatterplot of age vs. fare, colored by class
sns.scatterplot(x='age', y='fare', hue='class', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
# Create a histogram of ages, with separate colors for men and women
sns.histplot(data=df, x='age', hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# Create a countplot of passenger survival, colored by class
sns.countplot(x='survived', hue='class', data=df)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
# Plot histogram of ticket prices
plt.figure(figsize=(8, 6))
sns.histplot(df['fare'], bins=20, kde=True,color='orange')
plt.title('Distribution of Ticket Prices')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %%
# Use Seaborn's histplot to visualize the distribution of fares for male and female passengers
sns.histplot(data=df, x='fare', hue='sex', kde=True, bins=20, palette=['pink', 'yellow'], alpha=0.7)

# Add a title and axis labels using Matplotlib
plt.title('Distribution of Ticket Fares by Gender')
plt.xlabel('Ticket Fare')
plt.ylabel('Density')

# Show the plot using Matplotlib
plt.show()

# %%
sns.histplot(data=df, x='fare', hue='sex',bins=20)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.barplot(x='sex',y='age',data=df,palette='husl')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
# Set the style of the plot using Seaborn
sns.set_style('darkgrid')

# Create a figure and axis object using Matplotlib
fig, ax = plt.subplots(figsize=(12,6))

# Use Seaborn's boxplot to visualize the distribution of ages for each gender and survival status
sns.boxplot(data=df, x='sex', y='age', hue='survived', palette='husl', ax=ax)

# Add a title and axis labels using Matplotlib
ax.set_title('Distribution of Age by Gender and Survival Status', fontsize=16)
ax.set_xlabel('Gender', fontsize=14)
ax.set_ylabel('Age', fontsize=14)

# Add a legend to clarify the meaning of 0 and 1 in the 'survived' variable
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Did Not Survive', 'Survived'])

# Show the plot using Matplotlib
plt.show()
